# %%
from src.get_data import read_params
import argparse
import mlflow
from mlflow.tracking import MlflowClient
from pprint import pprint
import joblib
import os

# os.chdir('E:\\Projects\\ML Ops\\simple_app')

def log_production_model(config_path):
    config = read_params(config_path)

    mlflow_config = config["mlflow_config"]

    model_name = mlflow_config["registered_model_name"]

    remote_sever_uri = mlflow_config["remote_server_uri"]
    mlflow.set_tracking_uri(remote_sever_uri)

    runs = mlflow.search_runs(experiment_ids=1)
    lowest = runs['metrics.mae'].sort_values(ascending=True)[0]
    lowest_run_id = runs[runs['metrics.mae'] == lowest]["run_id"][0]

    client = MlflowClient()
    for mv in client.search_model_versions(f"name='{model_name}'"):
        mv = dict(mv)
        pprint(mv, indent=4)

        if mv["run_id"] == lowest_run_id:
            current_version = mv["version"]
            logged_model = mv["source"]
            pprint(mv, indent=4)
            client.transition_model_version_stage(
                name=model_name,
                version=current_version,
                stage="Production"
            )
        else:
            current_version = mv["version"]
            client.transition_model_version_stage(
                name=model_name,
                version=current_version,
                stage="Staging"
            )
            
log_production_model("params.yaml")
# Out:
# {   'creation_timestamp': 1622545305761,
#     'current_stage': 'Staging',
#     'description': '',
#     'last_updated_timestamp': 1622552666298,
#     'name': 'ElasticNetWineModel',
#     'run_id': '9445bfe6702749969c5b1d369ad19968',
#     'run_link': '',
#     'source': './artifacts/1/9445bfe6702749969c5b1d369ad19968/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '1'}
# {   'creation_timestamp': 1622545549303,
#     'current_stage': 'Staging',
#     'description': '',
#     'last_updated_timestamp': 1622552666519,
#     'name': 'ElasticNetWineModel',
#     'run_id': '7b95c711f04e4f439cdb216fc82b0998',
#     'run_link': '',
#     'source': './artifacts/1/7b95c711f04e4f439cdb216fc82b0998/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '2'}
# {   'creation_timestamp': 1622545572857,
#     'current_stage': 'Staging',
#     'description': '',
#     'last_updated_timestamp': 1622552666674,
#     'name': 'ElasticNetWineModel',
#     'run_id': '93695249d9614d93b0619f95c70f7406',
#     'run_link': '',
#     'source': './artifacts/1/93695249d9614d93b0619f95c70f7406/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '3'}
# {   'creation_timestamp': 1622550337142,
#     'current_stage': 'Production',
#     'description': '',
#     'last_updated_timestamp': 1622552666768,
#     'name': 'ElasticNetWineModel',
#     'run_id': 'cd59ad8d11da4a23adec0f7218275c95',
#     'run_link': '',
#     'source': './artifacts/1/cd59ad8d11da4a23adec0f7218275c95/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '4'}
# {   'creation_timestamp': 1622550337142,
#     'current_stage': 'Production',
#     'description': '',
#     'last_updated_timestamp': 1622552666768,
#     'name': 'ElasticNetWineModel',
#     'run_id': 'cd59ad8d11da4a23adec0f7218275c95',
#     'run_link': '',
#     'source': './artifacts/1/cd59ad8d11da4a23adec0f7218275c95/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '4'}

# %%
pwd
# Out:
# 'E:\\Projects\\ML Ops\\simple_app'

# %%
from src.get_data import read_params
import argparse
import mlflow
from mlflow.tracking import MlflowClient
from pprint import pprint
import joblib
import os


def log_production_model(config_path):
    config = read_params(config_path)

    mlflow_config = config["mlflow_config"]

    model_name = mlflow_config["registered_model_name"]

    remote_server_uri = mlflow_config["remote_server_uri"]

    mlflow.set_tracking_uri(remote_server_uri)

    runs = mlflow.search_runs(experiment_ids=1)
    print(runs.columns)
    lowest = runs["metrics.mae"].sort_values(ascending=True)[0]
    lowest_run_id = runs[runs["metrics.mae"] == lowest]["run_id"][0]

    client = MlflowClient()
    for mv in client.search_model_versions(f"name='{model_name}'"):
        mv = dict(mv)

        if mv["run_id"] == lowest_run_id:
            current_version = mv["version"]
            logged_model = mv["source"]
            pprint(mv, indent=4)
            client.transition_model_version_stage(
                name=model_name,
                version=current_version,
                stage="Production"
            )
        else:
            current_version = mv["version"]
            client.transition_model_version_stage(
                name=model_name,
                version=current_version,
                stage="Staging"
            )
log_production_model("params.yaml")
# Out:
# Index(['run_id', 'experiment_id', 'status', 'artifact_uri', 'start_time',
#        'end_time', 'metrics.rmse', 'metrics.r2', 'metrics.mae', 'params.alpha',
#        'params.l1_ratio', 'tags.mlflow.runName',
#        'tags.mlflow.source.git.commit', 'tags.mlflow.user',
#        'tags.mlflow.log-model.history', 'tags.mlflow.source.type',
#        'tags.mlflow.source.name'],
#       dtype='object')
# {   'creation_timestamp': 1622550337142,
#     'current_stage': 'Production',
#     'description': '',
#     'last_updated_timestamp': 1622551161895,
#     'name': 'ElasticNetWineModel',
#     'run_id': 'cd59ad8d11da4a23adec0f7218275c95',
#     'run_link': '',
#     'source': './artifacts/1/cd59ad8d11da4a23adec0f7218275c95/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '4'}
